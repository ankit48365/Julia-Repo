# %% [markdown]
# # Data

# %%
import Pkg; 
Pkg.add("BenchmarkTools");
Pkg.add("DataFrames");
Pkg.add("CSV");
Pkg.add("XLSX");
# Out:
#    Updating registry at `/srv/julia/pkg/registries/General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
#     Fetching: [======>                                  ]
# Fetching: [========================================>]  100.0 %                            ]  28.7 % [=================>                       ]  41.4 %54.1 %         ]  77.1 %
#   Resolving package versions...
#   Installed UnPack ─────────────────────── v1.0.1
#   Installed StatsFuns ──────────────────── v0.9.5
#   Installed ColorTypes ─────────────────── v0.10.3
#   Installed BenchmarkTools ─────────────── v0.5.0
#   Installed Tables ─────────────────────── v1.0.4
#   Installed OffsetArrays ───────────────── v1.0.4
#   Installed Parameters ─────────────────── v0.12.1
#   Installed Colors ─────────────────────── v0.12.1
#   Installed WoodburyMatrices ───────────── v0.5.2
#   Installed Juno ───────────────────────── v0.8.2
#   Installed BinaryProvider ─────────────── v0.5.10
#   Installed ArrayInterface ─────────────── v2.8.7
#   Installed SpecialFunctions ───────────── v0.10.3
#   Installed FileIO ─────────────────────── v1.3.0
#   Installed StaticArrays ───────────────── v0.12.3
#   Installed TimeZones ──────────────────── v0.10.5
#   Installed ExprTools ──────────────────── v0.1.1
#   Installed DataStructures ─────────────── v0.17.17
#   Installed Distributions ──────────────── v0.23.3
#   Installed FiniteDiff ─────────────────── v2.3.2
#   Installed OpenBLAS_jll ───────────────── v0.3.9+4
#   Installed CompilerSupportLibraries_jll ─ v0.3.3+0
#   Installed FFTW ───────────────────────── v1.2.2
#   Installed Distances ──────────────────── v0.9.0
#   Installed ForwardDiff ────────────────── v0.10.10
#   Installed DataAPI ────────────────────── v1.3.0
#   Installed MKL_jll ────────────────────── v2020.1.216+0
#   Installed Loess ──────────────────────── v0.5.0
#   Installed Contour ────────────────────── v0.5.3
#   Installed Interpolations ─────────────── v0.12.10
#   Installed Zlib_jll ───────────────────── v1.2.11+10
#   Installed FillArrays ─────────────────── v0.8.10
#   Installed OrderedCollections ─────────── v1.2.0
# ######################################################################### 100.0%##O#- #
# ######################################################################### 100.0%##O=#  #
# ######################################################################### 100.0%##O#- #
#    Updating `~/Project.toml`
#   [6e4b80f9] + BenchmarkTools v0.5.0
#    Updating `~/Manifest.toml`
#   [4fba245c] ↑ ArrayInterface v2.6.1 ⇒ v2.8.7
#   [6e4b80f9] + BenchmarkTools v0.5.0
#   [b99e7846] ↑ BinaryProvider v0.5.8 ⇒ v0.5.10
#   [3da002f7] ↑ ColorTypes v0.10.0 ⇒ v0.10.3
#   [5ae59095] ↑ Colors v0.12.0 ⇒ v0.12.1
#   [e66e0078] ↑ CompilerSupportLibraries_jll v0.3.1+0 ⇒ v0.3.3+0
#   [d38c429a] ↑ Contour v0.5.2 ⇒ v0.5.3
#   [9a962f9c] ↑ DataAPI v1.1.0 ⇒ v1.3.0
#   [864edb3b] ↑ DataStructures v0.17.10 ⇒ v0.17.17
#   [b4f34e82] ↑ Distances v0.8.2 ⇒ v0.9.0
#   [31c24e10] ↑ Distributions v0.23.1 ⇒ v0.23.3
#   [e2ba6199] ↑ ExprTools v0.1.0 ⇒ v0.1.1
#   [7a1cc6ca] ↑ FFTW v1.2.0 ⇒ v1.2.2
#   [5789e2e9] ↑ FileIO v1.2.4 ⇒ v1.3.0
#   [1a297f60] ↑ FillArrays v0.8.5 ⇒ v0.8.10
#   [6a86dc24] ↑ FiniteDiff v2.3.0 ⇒ v2.3.2
#   [f6369f11] ↑ ForwardDiff v0.10.9 ⇒ v0.10.10
#   [a98d9a8b] ↑ Interpolations v0.12.5 ⇒ v0.12.10
#   [e5e0dc1b] ↑ Juno v0.8.1 ⇒ v0.8.2
#   [4345ca2d] ↓ Loess v0.5.1 ⇒ v0.5.0
#   [856f044c] ↑ MKL_jll v2019.0.117+2 ⇒ v2020.1.216+0
#   [6fe1bfb0] ↑ OffsetArrays v1.0.3 ⇒ v1.0.4
#   [4536629a] ↑ OpenBLAS_jll v0.3.7+9 ⇒ v0.3.9+4
#   [bac558e1] ↑ OrderedCollections v1.1.0 ⇒ v1.2.0
#   [d96e819e] ↑ Parameters v0.12.0 ⇒ v0.12.1
#   [276daf66] ↑ SpecialFunctions v0.10.0 ⇒ v0.10.3
#   [90137ffa] ↑ StaticArrays v0.12.1 ⇒ v0.12.3
#   [4c63d2b9] ↑ StatsFuns v0.9.4 ⇒ v0.9.5
#   [bd369af6] ↑ Tables v1.0.3 ⇒ v1.0.4
#   [f269a46b] ↓ TimeZones v1.0.1 ⇒ v0.10.5
#   [3a884ed6] + UnPack v1.0.1
#   [efce3f68] ↑ WoodburyMatrices v0.5.1 ⇒ v0.5.2
#   [83775a58] ↑ Zlib_jll v1.2.11+9 ⇒ v1.2.11+10
#    Building TimeZones → `/srv/julia/pkg/packages/TimeZones/joMm3/deps/build.log`
#    Building FFTW ─────→ `/srv/julia/pkg/packages/FFTW/kcXL6/deps/build.log`
#   Resolving package versions...
#    Updating `~/Project.toml`
#   [a93c6f00] + DataFrames v0.20.2
#    Updating `~/Manifest.toml`
#  [no changes]
#   Resolving package versions...
#    Updating `~/Project.toml`
#   [336ed68f] + CSV v0.5.26
#    Updating `~/Manifest.toml`
#  [no changes]
#   Resolving package versions...
#   Installed XLSX ──── v0.7.2
#   Installed ZipFile ─ v0.9.2
#    Updating `~/Project.toml`
#   [fdbf4ff8] + XLSX v0.7.2
#    Updating `~/Manifest.toml`
#   [fdbf4ff8] + XLSX v0.7.2
#   [a5390f91] + ZipFile v0.9.2

# %%
using BenchmarkTools
using DataFrames
using DelimitedFiles
using CSV
using XLSX
# Out:
# ┌ Info: Precompiling BenchmarkTools [6e4b80f9-dd63-53aa-95a3-0cdb28fa8baf]
# └ @ Base loading.jl:1260
# ┌ Info: Precompiling DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0]
# └ @ Base loading.jl:1260
# ┌ Info: Precompiling CSV [336ed68f-0bac-5ca0-87d4-7b16caf5d00b]
# └ @ Base loading.jl:1260
# ┌ Info: Precompiling XLSX [fdbf4ff8-1666-58a4-91e7-1b58723a45e0]
# └ @ Base loading.jl:1260

# %% [markdown]
# Add Question Mark before to understand the command - ?download

# %%
?download
# Out:
# search: download
#   download(url::AbstractString, [localfile::AbstractString])
#
#   Download a file from the given url, optionally renaming it to the given
#   local file name. If no filename is given this will download into a
#   randomly-named file in your temp directory. Note that this function relies
#   on the availability of external tools such as curl, wget or fetch to
#   download the file and is provided for convenience. For production use or
#   situations in which more options are needed, please use a package that
#   provides the desired functionality instead.
#
#   Returns the filename of the downloaded file.
#
#   ────────────────────────────────────────────────────────────────────────────
#
#   download(url::Union{AbstractString, AbstractPath}, localfile::AbstractPath)
#
#   Download a file from the remote url and save it to the localfile path.

# %%
P = download("https://raw.githubusercontent.com/nassarhuda/easy_data/master/programming_languages.csv",
    "programminglanguages.csv")
# Out:
# "programminglanguages.csv"

# %% [markdown]
# ## 📂 Read your data from text files.

# %% [markdown]
# ## Delimiter Package

# %%
;head programminglanguages.csv
# Out:
# year,language
# 1951,Regional Assembly Language
# 1952,Autocode
# 1954,IPL
# 1955,FLOW-MATIC
# 1957,FORTRAN
# 1957,COMTRAN
# 1958,LISP
# 1958,ALGOL 58
# 1959,FACT

# %% [markdown]
# Head was a quick way to read CSV file, However, P,H ....synatx below, defines the file has a header and ',' signifies the delimiter value, after that when you enter P, H, it will give you the output

# %%
#=
readdlm(source, 
    delim::AbstractChar, 
    T::Type, 
    eol::AbstractChar; 
    header=false, 
    skipstart=0, 
    skipblanks=true, 
    use_mmap, 
    quotes=true, 
    dims, 
    comments=false, 
    comment_char='#')
=#
P,H = readdlm("programminglanguages.csv",',';header=true);

# %%
P
# Out:
# 73×2 Array{Any,2}:
#  1951  "Regional Assembly Language"
#  1952  "Autocode"
#  1954  "IPL"
#  1955  "FLOW-MATIC"
#  1957  "FORTRAN"
#  1957  "COMTRAN"
#  1958  "LISP"
#  1958  "ALGOL 58"
#  1959  "FACT"
#  1959  "COBOL"
#  1959  "RPG"
#  1962  "APL"
#  1962  "Simula"
#     ⋮
#  2003  "Scala"
#  2005  "F#"
#  2006  "PowerShell"
#  2007  "Clojure"
#  2009  "Go"
#  2010  "Rust"
#  2011  "Dart"
#  2011  "Kotlin"
#  2011  "Red"
#  2011  "Elixir"
#  2012  "Julia"
#  2014  "Swift"

# %%
H
# Out:
# 1×2 Array{AbstractString,2}:
#  "year"  "language"

# %% [markdown]
# ## CSV Package

# %%
C = CSV.read("programminglanguages.csv");

# %% [markdown]
# 1:5 for range of Rows and second part for range of columns left empty

# %%
C[1:5,:]
# Out:
# 5×2 DataFrame
# │ Row │ year  │ language                   │
# │     │ Int64 │ String                     │
# ├─────┼───────┼────────────────────────────┤
# │ 1   │ 1951  │ Regional Assembly Language │
# │ 2   │ 1952  │ Autocode                   │
# │ 3   │ 1954  │ IPL                        │
# │ 4   │ 1955  │ FLOW-MATIC                 │
# │ 5   │ 1957  │ FORTRAN                    │

# %% [markdown]
# Diffrence Between - Delimiter and CSV package type of ...notice the o/p above was diffrent too...

# %%
print("this is delimiter package type of .....")
@show typeof(P);
print("this is CSV package type of .....")
@show typeof(C);
# Out:
# this is delimiter package type of .....typeof(P) = Array{Any,2}
# this is CSV package type of .....typeof(C) = DataFrame

# %% [markdown]
# ## Importing Data

# %% [markdown]
# ### JLD FIle Import

# %%
Pkg.add("JLD")
Pkg.add("NPZ")
Pkg.add("RData")
Pkg.add("MAT")
# Out:
#   Resolving package versions...
#    Updating `~/Project.toml`
#  [no changes]
#    Updating `~/Manifest.toml`
#  [no changes]
#   Resolving package versions...
#    Updating `~/Project.toml`
#  [no changes]
#    Updating `~/Manifest.toml`
#  [no changes]
#   Resolving package versions...
#    Updating `~/Project.toml`
#   [df47a6cb] + RData v0.6.3
#    Updating `~/Manifest.toml`
#  [no changes]
#   Resolving package versions...
#   Installed BufferedStreams ─ v1.0.0
#   Installed MAT ───────────── v0.8.0
#    Updating `~/Project.toml`
#   [23992714] + MAT v0.8.0
#    Updating `~/Manifest.toml`
#   [e1450e63] + BufferedStreams v1.0.0
#   [23992714] + MAT v0.8.0

# %%
using JLD
jld_data = JLD.load("data/mytempdata.jld")
save("mywrite.jld", "A", jld_data)
# Out:
# ┌ Info: Precompiling JLD [4138dd39-2aa7-5051-a626-17a0bb65d9c8]
# └ @ Base loading.jl:1260
# File data/mytempdata.jld cannot be found
#
# Stacktrace:
#  [1] error(::String, ::String, ::String) at ./error.jl:42
#  [2] jldopen(::String, ::Bool, ::Bool, ::Bool, ::Bool, ::Bool; mmaparrays::Bool, compatible::Bool, compress::Bool) at /srv/julia/pkg/packages/JLD/jeGJb/src/JLD.jl:153
#  [3] jldopen(::String, ::String; mmaparrays::Bool, compatible::Bool, compress::Bool) at /srv/julia/pkg/packages/JLD/jeGJb/src/JLD.jl:231
#  [4] jldopen(::String, ::String) at /srv/julia/pkg/packages/JLD/jeGJb/src/JLD.jl:231
#  [5] jldopen(::JLD.var"#42#44", ::String, ::Vararg{String,N} where N; kws::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /srv/julia/pkg/packages/JLD/jeGJb/src/JLD.jl:241
#  [6] jldopen(::Function, ::String, ::String) at /srv/julia/pkg/packages/JLD/jeGJb/src/JLD.jl:241
#  [7] load(::FileIO.File{FileIO.DataFormat{:JLD}}) at /srv/julia/pkg/packages/JLD/jeGJb/src/JLD.jl:1245
#  [8] load(::String; options::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /srv/julia/pkg/packages/FileIO/ZknoK/src/loadsave.jl:118
#  [9] load(::String) at /srv/julia/pkg/packages/FileIO/ZknoK/src/loadsave.jl:118
#  [10] top-level scope at In[5]:2

# %%
using NPZ
npz_data = npzread("data/mytempdata.npz")
npzwrite("mywrite.npz", npz_data)
# Out:
# ┌ Info: Precompiling NPZ [15e1cf62-19b3-5cfa-8e77-841668bca605]
# └ @ Base loading.jl:1260
# SystemError: opening file "data/mytempdata.npz": No such file or directory
#
# Stacktrace:
#  [1] systemerror(::String, ::Int32; extrainfo::Nothing) at ./error.jl:168
#  [2] #systemerror#50 at ./error.jl:167 [inlined]
#  [3] systemerror at ./error.jl:167 [inlined]
#  [4] open(::String; read::Nothing, write::Nothing, create::Nothing, truncate::Nothing, append::Nothing) at ./iostream.jl:254
#  [5] open at ./iostream.jl:246 [inlined]
#  [6] npzread(::String) at /srv/julia/pkg/packages/NPZ/OBINJ/src/NPZ.jl:240
#  [7] top-level scope at In[8]:2

# %%
using RData
R_data = RData.load("data/mytempdata.rda")
# We'll need RCall to save here. https://github.com/JuliaData/RData.jl/issues/56
using RCall
@rput R_data
R"save(R_data, file=\"mywrite.rda\")"
# Out:
# ┌ Info: Precompiling RData [df47a6cb-8c03-5eed-afd8-b6050d6c41da]
# └ @ Base loading.jl:1260
# Error encountered while loading "data/mytempdata.rda".
#
# Fatal error:
# SystemError: opening file "data/mytempdata.rda": No such file or directory
#
# Stacktrace:
#  [1] handle_error(::SystemError, ::FileIO.File{FileIO.DataFormat{:RData}}) at /srv/julia/pkg/packages/FileIO/ZknoK/src/error_handling.jl:82
#  [2] handle_exceptions(::Array{Any,1}, ::String) at /srv/julia/pkg/packages/FileIO/ZknoK/src/error_handling.jl:77
#  [3] load(::FileIO.Formatted; options::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /srv/julia/pkg/packages/FileIO/ZknoK/src/loadsave.jl:186
#  [4] load(::FileIO.Formatted) at /srv/julia/pkg/packages/FileIO/ZknoK/src/loadsave.jl:166
#  [5] load(::String; options::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /srv/julia/pkg/packages/FileIO/ZknoK/src/loadsave.jl:118
#  [6] load(::String) at /srv/julia/pkg/packages/FileIO/ZknoK/src/loadsave.jl:118
#  [7] top-level scope at In[9]:2

# %%
using MAT
Matlab_data = matread("data/mytempdata.mat")
matwrite("mywrite.mat",Matlab_data)
# Out:
# ┌ Info: Precompiling MAT [23992714-dd62-5051-b70f-ba57cb901cac]
# └ @ Base loading.jl:1260
# File "data/mytempdata.mat" does not exist and create was not specified
#
# Stacktrace:
#  [1] error(::String) at ./error.jl:33
#  [2] matopen(::String, ::Bool, ::Bool, ::Bool, ::Bool, ::Bool, ::Bool) at /srv/julia/pkg/packages/MAT/2LFMT/src/MAT.jl:44
#  [3] matopen(::String, ::String; compress::Bool) at /srv/julia/pkg/packages/MAT/2LFMT/src/MAT.jl:88
#  [4] matopen at /srv/julia/pkg/packages/MAT/2LFMT/src/MAT.jl:88 [inlined]
#  [5] #matopen#2 at /srv/julia/pkg/packages/MAT/2LFMT/src/MAT.jl:97 [inlined]
#  [6] matopen at /srv/julia/pkg/packages/MAT/2LFMT/src/MAT.jl:97 [inlined]
#  [7] matread(::String) at /srv/julia/pkg/packages/MAT/2LFMT/src/MAT.jl:130
#  [8] top-level scope at In[10]:2
